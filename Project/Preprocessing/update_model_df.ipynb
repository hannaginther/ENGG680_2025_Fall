# %% [markdown]
# <a href="https://colab.research.google.com/github/hannaginther/ENGG680_2025_Fall/blob/main/Project/update_model_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_v1 = pd.read_feather('/content/drive/MyDrive/Sparcs_Datafiles/model_data_v1.feather')

# %%
# Drop discharge year
df_v2 = df_v1.copy()
df_v2.drop(columns=['discharge_year'], inplace=True)

# %%
for payer in df_v2.columns[df_v2.columns.str.contains('payer')]:
  print(payer)
# Out:
# payer_medicaid
# payer_medicare
# payer_private_insurance
# payer_self_pay
# payer_blue_cross
# payer_other
# payer_gov_va
# payer_corrections
# payer_managed_care

# %%
# Combine payer cols to major payer types (based on feature importance)

def map_payment_types(row):
  payers = []

  # Major Categories
  # 1. Medicare
  if row.get('payer_medicare', 0) == 1:
    payers.append('Medicare')

  # 2. Medicaid
  if row.get('payer_medicaid', 0) == 1:
    payers.append('Medicaid')

  # 3. Private insurance
  if row.get('payer_private_insurance', 0) == 1:
    payers.append('Private insurance')

  # 4. BlueCross
  if row.get('payer_blue_cross', 0) == 1:
    payers.append('BlueCross')

  # 5. Everything else -> Other
  if (
      row.get('payer_managed_care', 0) == 1 or
      row.get('payer_self_pay', 0) == 1 or
      row.get('payer_corrections', 0) == 1 or
      row.get('payer_gov_va', 0) == 1 or
      row.get('payer_other', 0) == 1
  ):
    payers.append('Other')

  if len(payers) == 0:
    return 'Unknown'

  return ', '.join(sorted(payers))

# %%
# Apply payer changes to df
df_v2['payment_type'] = df_v2.apply(map_payment_types,axis=1)
df_v2['payment_type'] = df_v2['payment_type'].astype('object')

# %%
# Drop old payer cols
payer_cols = [
    'payer_medicaid',
    'payer_medicare',
    'payer_private_insurance',
    'payer_self_pay',
    'payer_blue_cross',
    'payer_other',
    'payer_gov_va',
    'payer_corrections',
    'payer_managed_care'
]
df_v2.drop(columns=payer_cols, inplace=True)

# %%
df_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238636 entries, 0 to 4238635
# Data columns (total 19 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   health_service_area  object
#  1   hospital_county      object
#  2   facility_id          object
#  3   age_group            object
#  4   zip_code             object
#  5   gender               object
#  6   race                 object
#  7   ethnicity            object
#  8   length_of_stay       int64
#  9   admission_type       object
#  10  ccsr_dx_code         object
#  11  ccsr_px_code         object
#  12  apr_drg_code         object
#  13  apr_mdc_code         object
#  14  apr_severity_code    object
#  15  apr_mortality_risk   object
#  16  apr_med_surg_desc    object
#  17  num_payment_types    int64
#  18  payment_type         object
# dtypes: int64(2), object(17)
# memory usage: 614.4+ MB

# %%
df_v2.value_counts('payment_type')
# Out:
# payment_type
# Medicaid                                  1037669
# Medicare                                   561642
# Medicaid, Medicare                         549050
# Private insurance                          468121
# BlueCross                                  297818
# Medicare, Private insurance                275686
# Medicaid, Other                            219943
# BlueCross, Medicare                        200650
# Other                                      170353
# Medicare, Other                            117031
# Other, Private insurance                    76304
# BlueCross, Other                            57216
# Medicaid, Medicare, Other                   51721
# Medicaid, Private insurance                 27082
# Medicare, Other, Private insurance          26675
# BlueCross, Medicare, Other                  26501
# Medicaid, Medicare, Private insurance       16553
# BlueCross, Medicaid                         15263
# BlueCross, Private insurance                11576
# BlueCross, Medicare, Private insurance      10317
# BlueCross, Medicaid, Medicare                9123
# Medicaid, Other, Private insurance           5776
# BlueCross, Medicaid, Other                   3493
# BlueCross, Other, Private insurance          2434
# BlueCross, Medicaid, Private insurance        492
# Unknown                                       147
# Name: count, dtype: int64

# %%
df_v2_clf = df_v2.copy()

def categorize_los(x):
    if x <= 2:
        return "Short"
    elif x <= 5:
        return "Moderate"
    elif x <= 10:
        return "Long"
    else:
        return "Extreme"

df_v2_clf['los_category'] = df_v2_clf['length_of_stay'].apply(categorize_los)

# %%
df_v2_clf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238636 entries, 0 to 4238635
# Data columns (total 20 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   health_service_area  object
#  1   hospital_county      object
#  2   facility_id          object
#  3   age_group            object
#  4   zip_code             object
#  5   gender               object
#  6   race                 object
#  7   ethnicity            object
#  8   length_of_stay       int64
#  9   admission_type       object
#  10  ccsr_dx_code         object
#  11  ccsr_px_code         object
#  12  apr_drg_code         object
#  13  apr_mdc_code         object
#  14  apr_severity_code    object
#  15  apr_mortality_risk   object
#  16  apr_med_surg_desc    object
#  17  num_payment_types    int64
#  18  payment_type         object
#  19  los_category         object
# dtypes: int64(2), object(18)
# memory usage: 646.8+ MB

# %%
pd.crosstab(
    df_v2_clf['los_category'],
    pd.cut(df_v2_clf['length_of_stay'], bins=[0,2,5,10,999], right=True)
)
# Out:
# length_of_stay   (0, 2]   (2, 5]  (5, 10]  (10, 999]
# los_category
# Extreme               0        0        0     538306
# Long                  0        0   695012          0
# Moderate              0  1346262        0          0
# Short           1659056        0        0          0

# %%
df_v2_clf[['length_of_stay', 'los_category']].sample(20)
# Out:
#          length_of_stay los_category
# 3596970               2        Short
# 857156               15      Extreme
# 2738299               5     Moderate
# 188724                3     Moderate
# 3585319              11      Extreme
# 3910561              24      Extreme
# 3178425               4     Moderate
# 4115016              10         Long
# 3799519               1        Short
# 825930                3     Moderate
# 1285623              15      Extreme
# 3234945               2        Short
# 2404115               1        Short
# 3694608               2        Short
# 705976                5     Moderate
# 1204670               3     Moderate
# 1598486               1        Short
# 2264958               1        Short
# 1667599               6         Long
# 4122578              36      Extreme

# %%
df_v2_clf.to_feather('/content/drive/MyDrive/Sparcs_Datafiles/model_df_clf_v2.feather')
