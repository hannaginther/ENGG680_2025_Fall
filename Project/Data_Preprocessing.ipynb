# %% [markdown]
# <a href="https://colab.research.google.com/github/hannaginther/ENGG680_2025_Fall/blob/main/Project/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ENGG680 - Introduction to Digital Engineering**
# ## *Group Project: Implementing ML model for Hospital Length of Stay Prediction*

# %% [markdown]
# ## **SPARCS Data Preprocessing**
# ###Goals: Understand data, statistical analysis, address outliers and missing values

# %% [markdown]
# ###Step 1: Import Libraries, Load DataFrame

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
