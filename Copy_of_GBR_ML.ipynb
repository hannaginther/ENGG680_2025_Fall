# %% [markdown]
# <a href="https://colab.research.google.com/github/hannaginther/ENGG680_2025_Fall/blob/main/Copy_of_GBR_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Creating a Gradient Boosted Regression ML Model**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git config --global user.email "gintherhanna@gmail.com"
# !git config --global user.email "hannaginther"

# %%
# Import libraries

# %%
# Import DataFrame
